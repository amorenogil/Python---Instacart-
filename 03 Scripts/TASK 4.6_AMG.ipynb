# %% [markdown]
# # 01. Importing libraries and creating a path

# %%
#importing libraries
import pandas as pd
import numpy as np
import os

# %%
path= r'C:\Users\amore\Documents\Data Analyst course\Data Immersion\Achievement 4_python\Instacard_basket_analysis_29_01_2023'

# %% [markdown]
# # 02. Task 4.6

# %%
#Q3 Import the orders_products_combined dataframe from the pickle file
df_ords_combined=pd.read_pickle(os.path.join(path,'02 Data','Prepared Data','orders_products_combined.pkl'))

# %%
#Q4 checking the newly imported dataframe
df_ords_combined
# Out:
#           order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0          2539329        1    prior             1                   2
# 1          2539329        1    prior             1                   2
# 2          2539329        1    prior             1                   2
# 3          2539329        1    prior             1                   2
# 4          2539329        1    prior             1                   2
# ...            ...      ...      ...           ...                 ...
# 32434484   2977660   206209    prior            13                   1
# 32434485   2977660   206209    prior            13                   1
# 32434486   2977660   206209    prior            13                   1
# 32434487   2977660   206209    prior            13                   1
# 32434488   2977660   206209    prior            13                   1
#
#           time_of_the_order  days_since_prior_order  First purchase  \
# ...

# %%
df_ords_combined.shape
# Out:
# (32434489, 12)

# %%
# Importing the products dataframe
df_prods=pd.read_csv(os.path.join(path,'02 Data','Prepared Data','products_clean.csv'), index_col=False)

# %%
#checking the df_prods dataframe
df_prods
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49667       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49668       49685                 En Croute Roast Hazelnut Cranberry
# 49669       49686                                   Artisan Baguette
# 49670       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49671       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
df_prods.shape
# Out:
# (49672, 5)

# %%
#Q5 Merging the df_ords_combined and df_prods using the "product_id"column
df_def = df_prods.merge(df_ords_combined, on='product_id')

# %%
#Q6 Confirming the merge 
df_def.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   3139998      138    prior            28                   6
# 1   1977647      138    prior            30                   6
# 2    389851      709    prior             2                   0
# 3    652770      764    prior             1                   3
# 4   1813452      764    prior             3                   4
#
#    time_of_the_order  days_since_prior_order  First purchase  \
# 0                 11                     3.0           False
# ...

# %%
#Q6
df_def['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
#Q7 Export the dataframe as orders_products_merged in a suitable format
df_def.to_pickle(os.path.join(path, '02 Data','Prepared Data','orders_products_merged.pkl'))

# %%
df_def.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.csv'),index=False)
